# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from pandas import DataFrame as df
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

from sklearn.metrics import plot_confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, SGDClassifier #A variant regression for classification tasks!
from sklearn.naive_bayes import GaussianNB as NaiveBayes
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import log_loss
from sklearn.cluster import KMeans

import re
import string
import pickle
from string import punctuation
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords, wordnet

# %%
# Task 1: Loading Dataset
data = pd.read_csv('21204829.csv')

# %% [markdown]
# Based on the analysis, there is no strong evidence to conclude that the category of an article and its headline
# are associated or dependent on each other. The p-value of 0.4695 indicates that there is a 46.95% probability of
# observing such a large chi-square statistic under the assumption that the category and headline are independent.
#
# The significant result suggests that the category of the article and author are not independent and that changes
# or patterns in one variable are associated with changes or patterns in the other variable.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         8000 non-null   int64
#  1   category           7980 non-null   object
#  2   headline           7978 non-null   object
#  3   authors            6926 non-null   object
#  4   link               7984 non-null   object
#  5   short_description  7133 non-null   object
#  6   date               7985 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 437.6+ KB

# %%
data.head()
# Out:
#    Unnamed: 0      category  \
# 0           0  QUEER VOICES
# 1           1  QUEER VOICES
# 2           2  QUEER VOICES
# 3           3         TASTE
# 4           4  QUEER VOICES
#
#                                             headline  \
# 0  Massachusetts Schools Prepare To Offer LGBTQ-I...
# 1  The 5 Best Grindr (Etc.) Locations in New York...
# 2  Gay Guys Get Personal And Ask Straight Men All...
# 3  Sarah Huckabee Sanders Actually Has An A+ Trol...
# 4  How Trans Rights Became The Civil Rights Strug...
#
#                                authors  \
# 0                         Sara Boboltz
# 1  Renato Barucco, Contributor\nAuthor
# 2                James Michael Nichols
# 3                             Ed Mazza
# 4                                  NaN
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/massachus...
# 1  https://www.huffingtonpost.com/entry/the-5-bes...
# 2  https://www.huffingtonpost.com/entry/gay-men-a...
# 3  https://www.huffingtonpost.com/entry/sarah-huc...
# 4  https://www.huffingtonpost.comhttp://www.polic...
#
#                                    short_description        date
# 0  Expect lectures on the Stonewall uprising, Lan...  2018-04-24
# 1  Hordes of gay and bi-curious men scan the city...  2013-11-09
# 2         "How often do you think about your penis?"  2016-01-09
# 3      She's making her critics eat some humble pie.  2017-12-14
# 4  Deep into the dog days of last August and bare...  2014-04-06

# %%
data.shape
# Out:
# (8000, 7)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'category', 'headline', 'authors', 'link',
#        'short_description', 'date'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Unnamed: 0              0
# category               20
# headline               22
# authors              1074
# link                   16
# short_description     867
# date                   15
# dtype: int64

# %%
# Drop rows with missing values
data.dropna(inplace=True)

# %%
# Dropping the unnamed column as it holds no significance in analysing the data
data = data.drop(["Unnamed: 0"], axis=1)

# %%
data.columns
# Out:
# Index(['category', 'headline', 'authors', 'link', 'short_description', 'date'], dtype='object')

# %%
# top 2 Categories of news in our datset
# https://www.kaggle.com/code/shivamburnwal/news-articles-classification
data.category.value_counts()[:2]
# Out:
# category
# QUEER VOICES    4377
# TASTE           1784
# Name: count, dtype: int64

# %%
# https://www.kaggle.com/code/shivamburnwal/news-articles-classification
# our unique labels of text which are to be classified.
# Check the unique values in the 'category' column
unique_categories = data['category'].dropna().unique()
print("Unique Categories:")
print(unique_categories)
# Out:
# Unique Categories:
# ['QUEER VOICES' 'TASTE']

# %%
# https://practicaldatascience.co.uk/machine-learning/how-to-preprocess-text-for-nlp-in-four-easy-steps
# Once the data have been loaded, the next common step most data scientists follow is to merge the 
# individual text columns together into a single column. 
# Sometimes this can throw away potentially useful features, but it’s usually fine on most projects.

#Authors can go in a separate column

# df = data
# df['all_text'] = data['headline'].astype(str) + " " + data['short_description'].astype(str) + " " + data['authors'].astype(str)
# df['label'] = data['category']
# del df['category']
# del df['headline']
# del df['authors']
# del df['link']
# del df['short_description']
# del df['date']
# df.head(10)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table1 = pd.crosstab(data['category'], data['headline'])
contingency_table2 = pd.crosstab(data['category'], data['authors'])

# Perform chi-square test of independence
chi2, p_value, _, _ = chi2_contingency(contingency_table1)

# Print the chi-square statistic and p-value
print("Chi-square statistic for 'category' and 'headline':", chi2)
print("p-value for Contingency Table 1:", p_value)

# Perform chi-square test of independence
chi2, p_value, _, _ = chi2_contingency(contingency_table2)

# Print the chi-square statistic and p-value
print("Chi-square statistic for 'category' and 'author':", chi2)
print("p-value for Contingency Table 2:", p_value)

# Step 5: Explore author-specific insights
top_authors = data['authors'].value_counts().head(10)
top_headlines = data['headline'].value_counts().head(10)
for author, headline in zip(top_authors.index, top_headlines):
    author_categories = data[data['authors'] == author]['category'].unique()
    print(f"Author: {author}, Categories: {author_categories}")
    headline_categories = data[data['headline'] == headline]['category'].unique()
    print(f"Headline: {headline}, Categories: {headline_categories}")
# Out:
# Chi-square statistic for 'category' and 'headline': 6160.999999999999
# p-value for Contingency Table 1: 0.4760503855701773
# Chi-square statistic for 'category' and 'author': 5772.924407716007
# p-value for Contingency Table 2: 0.0
# Author: Curtis M. Wong, Categories: ['QUEER VOICES']
# Headline: 3, Categories: []
# Author: James Michael Nichols, Categories: ['QUEER VOICES']
# Headline: 2, Categories: []
# Author: Julie R. Thomson, Categories: ['TASTE']
# Headline: 2, Categories: []
# Author: Noah Michelson, Categories: ['QUEER VOICES']
# Headline: 2, Categories: []
# Author: Jennifer Segal, ContributorChef, Recipe Developer and Busy Mom, Categories: ['TASTE']
# Headline: 1, Categories: []
# Author: Carly Ledbetter, Categories: ['TASTE']
# Headline: 1, Categories: []
# Author: Suzy Strutner, Categories: ['TASTE']
# Headline: 1, Categories: []
# Author: Michelangelo Signorile, Categories: ['QUEER VOICES']
# Headline: 1, Categories: []
# Author: Jennifer Segal, ContributorChef, Cookbook Author, Busy Mom, Categories: ['TASTE']
# Headline: 1, Categories: []
# Author: Cavan Sieczkowski, Categories: ['QUEER VOICES' 'TASTE']
# Headline: 1, Categories: []

# %%
# Get the most common terms for each category
categories = data['category'].unique()
for category in categories:
    # Filter the dataframe by category
    category_df = data[data['category'] == category]
    
    # Create a count vectorizer
    vectorizer = CountVectorizer()
    
    # Fit and transform the preprocessed text
    count_matrix = vectorizer.fit_transform(category_df['short_description'])
    
    # Get the feature names (terms)
    terms = vectorizer.get_feature_names()
    
    # Calculate the term frequencies
    term_frequencies = count_matrix.sum(axis=0)
    
    # Sort the terms by frequency
    sorted_terms = sorted(zip(terms, term_frequencies.tolist()[0]), key=lambda x: x[1], reverse=True)
    
    # Print the most common terms for the category
    print(f"Most common terms for category before preprocessing: {category}")
    for term, frequency in sorted_terms[:10]:
        print(f"{term}: {frequency}")
    print()


# Preprocessing
STOPWORDS = set(stopwords.words('english'))
punctuation = list(string.punctuation)
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    if isinstance(text, str):
        # Convert text to lowercase
        text = text.lower()

        # Remove punctuation
        text = ''.join([c for c in text if c not in punctuation])

        # Tokenize text
        tokens = text.split()

        # Remove stopwords and perform lemmatization
        tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in STOPWORDS]

        # Join tokens back to text
        text = ' '.join(tokens)
    else:
        text = ""
    
    return text

# Apply preprocessing to the 'short_description' column
data['preprocessed_text'] = data['short_description'].apply(preprocess_text)

# Get the most common terms for each category
categories = data['category'].unique()
for category in categories:
    # Filter the dataframe by category
    category_df = data[data['category'] == category]
    
    # Create a count vectorizer
    vectorizer = CountVectorizer()
    
    # Fit and transform the preprocessed text
    count_matrix = vectorizer.fit_transform(category_df['preprocessed_text'])
    
    # Get the feature names (terms)
    terms = vectorizer.get_feature_names()
    
    # Calculate the term frequencies
    term_frequencies = count_matrix.sum(axis=0)
    
    # Sort the terms by frequency
    sorted_terms = sorted(zip(terms, term_frequencies.tolist()[0]), key=lambda x: x[1], reverse=True)
    
    # Print the most common terms for the category
    print(f"Most common terms for category after preprocessing: {category}")
    for term, frequency in sorted_terms[:10]:
        print(f"{term}: {frequency}")
    print()
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Most common terms for category before preprocessing: QUEER VOICES
# the: 4770
# to: 2895
# and: 2597
# of: 2430
# in: 1677
# that: 1304
# is: 1195
# it: 1101
# for: 1042
# we: 749
#
# Most common terms for category before preprocessing: TASTE
# the: 1117
# and: 743
# to: 726
# of: 623
# you: 498
# it: 497
# is: 373
# in: 365
# with: 281
# are: 264
#
# Most common terms for category after preprocessing: QUEER VOICES
# gay: 523
# people: 419
# one: 310
# lgbt: 285
# new: 271
# community: 255
# year: 249
# week: 236
# love: 234
# life: 231
#
# Most common terms for category after preprocessing: TASTE
# make: 152
# recipe: 113
# food: 107
# one: 105
# like: 96
# time: 93
# good: 77
# day: 71
# delicious: 71
# easy: 70
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from wordcloud import WordCloud
import matplotlib.pyplot as plt



# Replace 'df' with the actual name of your DataFrame
preprocessed_headlines = data['headline'].apply(preprocess_text)

# Create the document-word matrix
vectorizer = CountVectorizer(max_features=1000)  # Adjust the max_features parameter as needed
document_word_matrix = vectorizer.fit_transform(preprocessed_headlines)

# Apply Latent Dirichlet Allocation (LDA)
num_topics = 5  # Specify the number of topics
lda = LatentDirichletAllocation(n_components=num_topics, random_state=42)
lda.fit(document_word_matrix)

# Get the top words for each topic
feature_names = vectorizer.get_feature_names()
top_words_per_topic = []
for topic_idx, topic in enumerate(lda.components_):
    top_words = [feature_names[i] for i in topic.argsort()[:-11:-1]]
    top_words_per_topic.append(top_words)

# Visualize the topics using word clouds
plt.figure(figsize=(12, 8))
for topic_idx, top_words in enumerate(top_words_per_topic):
    wordcloud = WordCloud(background_color='white').generate(' '.join(top_words))
    plt.subplot(2, 3, topic_idx+1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title('Topic ' + str(topic_idx+1))
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
df = data
del df['link']
del df['date']
df.columns
# Out:
# Index(['category', 'headline', 'authors', 'short_description',
#        'preprocessed_text'],
#       dtype='object')

# %%
# Calculate sentence length for each row
data['sentence_length'] = data['preprocessed_text'].str.split().apply(lambda x: len(x))

# Group the data by category and calculate mean and standard deviation of sentence length
category_stats = data.groupby('category')['sentence_length'].agg(['mean', 'std'])

# Print the statistics for each category
for category, stats in category_stats.iterrows():
    print(f"Category: {category}")
    print(f"Mean sentence length: {stats['mean']:.2f}")
    print(f"Standard deviation of sentence length: {stats['std']:.2f}")
    print()
# Out:
# Category: QUEER VOICES
# Mean sentence length: 12.24
# Standard deviation of sentence length: 7.90
#
# Category: TASTE
# Mean sentence length: 8.62
# Standard deviation of sentence length: 6.57

# %%
# Check for outliers in sentence length
q1 = data['sentence_length'].quantile(0.25)
q3 = data['sentence_length'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = data[(data['sentence_length'] < lower_bound) | (data['sentence_length'] > upper_bound)]
print("Outliers in Sentence Length:")
print(outliers)
# Out:
# Outliers in Sentence Length:
#           category                                           headline  \
# 180   QUEER VOICES  It's Not the '80s Anymore: Transition-Related ...
# 236          TASTE  Broccoli 'Breadcrumbs' Will Take Your Casserol...
# 245   QUEER VOICES  Gay American Men Shockingly Ignorant About HIV...
# 348   QUEER VOICES  He Told His Boyfriend, 'I Love You.' His Boyfr...
# 497   QUEER VOICES              Taking On Conversion Therapy in Texas
# ...            ...                                                ...
# 7560  QUEER VOICES                                     Go Fund Me Too
# 7737  QUEER VOICES   5 Things This Gay Man Learned From Dating Abroad
# 7816  QUEER VOICES                      10 Years of Marriage Equality
# 7840  QUEER VOICES  Remembering the Life, Love and Legacy of Audre...
# 7939         TASTE  Show Dad The Love With Dessert! 8 Father's Day...
#
#                                                 authors  \
# 180   James D. Esseks, ContributorDirector of the AC...
# 236   Epicurious, ContributorThe most trusted, autho...
# 245   John-Manuel Andriote, ContributorJournalist an...
# 348   Nathan Manske, ContributorFounder and Executiv...
# 497         Stuart Gaffney and John Lewis, Contributors
# ...                                                 ...
# 7560  Neal Wooten, ContributorWriter, artist and sta...
# 7737  Jeremy Helligar, ContributorJournalist, blogge...
# 7816  E. Denise Simmons, ContributorFormer mayor of ...
# 7840  Irene Monroe, ContributorNationally renowned A...
# 7939  Jennifer Segal, ContributorChef, Recipe Develo...
#
#                                       short_description  \
# 180   Determinations of what medical treatments are ...
# 236   I immediately wanted to top all my casseroles ...
# 245   More distressing than the profound lack of kno...
# 348   When Michael Coulter left Flint, Michigan, and...
# 497   When Ryan Kendall, a young gay man living in D...
# ...                                                 ...
# 7560  I'm officially announcing to the world that I,...
# 7737  Eight years, eight cities: Buenos Aires, Melbo...
# 7816  I am incredibly proud of the fact that Cambrid...
# 7840  Dr. Gloria I. Joseph has a treasure trove of m...
# 7939  This Father's Day, send dad out for a round of...
#
#                                       preprocessed_text  sentence_length
# 180   determination medical treatment covered medica...               31
# 236   immediately wanted top casserole pasta bakes b...               32
# 245   distressing profound lack knowledge hivaids am...               32
# 348   michael coulter left flint michigan went colle...               37
# 497   ryan kendall young gay man living denver heard...               32
# ...                                                 ...              ...
# 7560  im officially announcing world neal wooten blo...               35
# 7737  eight year eight city buenos aire melbourne ba...               43
# 7816  incredibly proud fact cambridge made decision ...               32
# 7840  dr gloria joseph treasure trove memory renowne...               35
# 7939  father day send dad round golf nap hammock kid...               32
#
# [90 rows x 6 columns]

# %%
# Plot boxplot for each category
plt.figure(figsize=(12, 6))
sns.boxplot(x='category', y='sentence_length', data=df)
plt.title('Outliers in Sentence Length by Category')
plt.xlabel('Category')
plt.ylabel('Sentence Length')
plt.xticks(rotation=45)
plt.show()

# %%
# Removing data based on sentence length might bias the dataset and affect the analysis of the relationship between 
# sentence length and the target variable (category).
# Data Distribution: Analysing the distribution of sentence lengths across categories to 
# assess if there are any significant differences
# Calculate sentence lengths for each category
category_lengths = {}
for category in df['category'].unique():
    sentences = df[df['category'] == category]['preprocessed_text']
    sentence_lengths = [len(sentence.split()) for sentence in sentences]
    category_lengths[category] = sentence_lengths

# Plot the distribution of sentence lengths for each category
plt.figure(figsize=(10, 6))
for category, lengths in category_lengths.items():
    plt.hist(lengths, bins=20, alpha=0.5, label=category)
plt.xlabel('Sentence Length')
plt.ylabel('Count')
plt.title('Distribution of Sentence Lengths by Category')
plt.legend()
plt.show()

# %%
# Data Balancing
# Calculate the initial distribution of categories
initial_distribution = df['category'].value_counts()

# Remove data based on sentence length
max_sentence_length = np.mean(df['sentence_length'])  # Define the maximum sentence length threshold
df_filtered = df[df['sentence_length'] <= max_sentence_length]

# Calculate the updated distribution of categories
updated_distribution = df_filtered['category'].value_counts()

# Visualize the initial and updated distributions
plt.figure(figsize=(12, 6))
plt.subplot(121)
initial_distribution.plot(kind='bar', color='blue')
plt.title('Initial Distribution')
plt.xlabel('Category')
plt.ylabel('Count')

plt.subplot(122)
updated_distribution.plot(kind='bar', color='green')
plt.title('Updated Distribution')
plt.xlabel('Category')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# Compare the distributions and assess the impact
print("Initial Distribution:\n", initial_distribution)
print("\nUpdated Distribution:\n", updated_distribution)

# Calculate sentence lengths for each category
category_lengths = {}
for category in df_filtered['category'].unique():
    sentences = df_filtered[df_filtered['category'] == category]['preprocessed_text']
    sentence_lengths = [len(sentence.split()) for sentence in sentences]
    category_lengths[category] = sentence_lengths

# Plot the distribution of sentence lengths for each category
plt.figure(figsize=(10, 6))
for category, lengths in category_lengths.items():
    plt.hist(lengths, bins=20, alpha=0.5, label=category)
plt.xlabel('Sentence Length')
plt.ylabel('Count')
plt.title('Distribution of Sentence Lengths by Category')
plt.legend()
plt.show()
# Out:
# Initial Distribution:
#  category
# QUEER VOICES    4377
# TASTE           1784
# Name: count, dtype: int64
#
# Updated Distribution:
#  category
# QUEER VOICES    2554
# TASTE           1315
# Name: count, dtype: int64

# %%
del df_filtered['short_description']
del df_filtered['sentence_length']
df.columns
# Out:
# Index(['category', 'headline', 'authors', 'short_description',
#        'preprocessed_text', 'sentence_length'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming you have already defined X and y
X = df_filtered.preprocessed_text
y = df_filtered.category

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Split the train set further into train and valid sets
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# Create DataFrames for the train, valid, and test sets
train_data = pd.DataFrame({'text': X_train, 'label': y_train})
valid_data = pd.DataFrame({'text': X_valid, 'label': y_valid})
test_data = pd.DataFrame({'text': X_test, 'label': y_test})

# Save the train, valid, and test data to separate CSV files
train_data.to_csv('train.csv', index=False)
valid_data.to_csv('valid.csv', index=False)
test_data.to_csv('test.csv', index=False)

# Print the shapes of the train, valid, and test sets
print(f"Train set shape: {train_data.shape}")
print(f"Valid set shape: {valid_data.shape}")
print(f"Test set shape: {test_data.shape}")
# Out:
# Train set shape: (2476, 2)
# Valid set shape: (619, 2)
# Test set shape: (774, 2)

# %%
df_filtered.isna().sum()
# Out:
# category             0
# headline             0
# authors              0
# preprocessed_text    0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

# Fill missing values with empty strings
train_data['text'] = train_data['text'].fillna('')
valid_data['text'] = valid_data['text'].fillna('')

# Convert text into a numeric representation
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(train_data['text'])
X_valid = vectorizer.transform(valid_data['text'])

# Get the labels
y_train = train_data['label']
y_valid = valid_data['label']

train_data.head()
# Out:
#                                                    text         label
# 1231                                  bustins feel good         TASTE
# 5141  gay lesbian falwell sr said partly blame 911 a...  QUEER VOICES
# 3273                                   bivalve fan need         TASTE
# 2489               free ice cream helping planet winwin         TASTE
# 1360                                         good thing         TASTE

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.models import save_model
from joblib import dump


# Define the models
models = [('Logistic Regression', LogisticRegression(max_iter=500)),
          ('Random Forest', RandomForestClassifier()),
          ('Linear SVC', LinearSVC()),
          ('Multinomial NaiveBayes', MultinomialNB()),
          ('SGD Classifier', SGDClassifier())]

names = []
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

# Iterate over each model
for name, clf in models:
    # Create a pipeline
    pipe = Pipeline([
        ('clf', clf),
    ])
    
    # Fit the pipeline on the training data
    pipe.fit(X_train, y_train)
    
    # Predict on the validation data
    y_pred = pipe.predict(X_valid)
    
    # Calculate evaluation metrics
    accuracy = accuracy_score(y_valid, y_pred)
    precision = precision_score(y_valid, y_pred, pos_label='QUEER VOICES')
    recall = recall_score(y_valid, y_pred, pos_label='QUEER VOICES')
    f1 = f1_score(y_valid, y_pred, pos_label='QUEER VOICES')  # Calculate the F1 score
    
    # Store the model and scores
    names.append(name)
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    
    # Save the model
    filename = f'{name}.joblib'
    dump(pipe, filename)
    
    # Calculate the confusion matrix
    plot_confusion_matrix(pipe, X_valid, y_valid, cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix - {name}")
    plt.show()

# Create a DataFrame with the scores
scores_df = pd.DataFrame({
    'Model': names,
    'Accuracy': accuracy_scores,
    'Precision': precision_scores,
    'Recall': recall_scores,
    'F1 Score': f1_scores
})

# Print the DataFrame
print(scores_df)
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#                     Model  Accuracy  Precision    Recall  F1 Score
# 0     Logistic Regression  0.799677   0.795964  0.914948  0.851319
# 1           Random Forest  0.780291   0.778761  0.907216  0.838095
# 2              Linear SVC  0.777060   0.800481  0.858247  0.828358
# 3  Multinomial NaiveBayes  0.827141   0.821510  0.925258  0.870303
# 4          SGD Classifier  0.783522   0.802381  0.868557  0.834158

# %%
# https://www.learndatasci.com/glossary/binary-classification/
ax = scores_df.plot.barh(x='Model', y=['Accuracy', 'Precision', 'Recall'], stacked=True)
ax.legend(ncol=len(models), bbox_to_anchor=(0, 1), loc='lower left', prop={'size': 14})
plt.xlabel('Score')
plt.ylabel('Model')
plt.title('Model Performance')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import f1_score
from tensorflow.keras.models import load_model

# Load train.csv and valid.csv files
train_data = pd.read_csv('train.csv')
valid_data = pd.read_csv('valid.csv')

# Fill missing values with empty strings
train_data['text'] = train_data['text'].fillna('')
valid_data['text'] = valid_data['text'].fillna('')


# Convert text into a numeric representation
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data['text'])
X_train = tokenizer.texts_to_sequences(train_data['text'])
X_valid = tokenizer.texts_to_sequences(valid_data['text'])

# Pad sequences to have the same length
max_sequence_length = max(len(sequence) for sequence in X_train)
X_train = pad_sequences(X_train, maxlen=max_sequence_length)
X_valid = pad_sequences(X_valid, maxlen=max_sequence_length)

# Get the labels
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(train_data['label'])
y_valid = label_encoder.transform(valid_data['label'])

# Define the model
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100, input_length=max_sequence_length))
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_valid, y_valid))

# Save the model
model.save('model.h5')

# Load the model
loaded_model = load_model('model.h5')

# Evaluate the model
y_pred_prob = loaded_model.predict(X_valid)
y_pred = (y_pred_prob > 0.5).astype(int)

# Compute evaluation metrics
accuracy = accuracy_score(y_valid, y_pred)
precision = precision_score(y_valid, y_pred)
recall = recall_score(y_valid, y_pred)
f1 = f1_score(y_valid, y_pred)

model_score = {
    'Model': 'CNN',
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1 Score': f1
}

print(model_score)
print('F1 Score:', f1)
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
# Out:
# Epoch 1/10
# 78/78 [==============================] - 3s 15ms/step - loss: 0.6051 - accuracy: 0.6648 - val_loss: 0.5452 - val_accuracy: 0.6656
# Epoch 2/10
# 78/78 [==============================] - 1s 11ms/step - loss: 0.3452 - accuracy: 0.8429 - val_loss: 0.4471 - val_accuracy: 0.7981
# Epoch 3/10
# 78/78 [==============================] - 1s 10ms/step - loss: 0.1004 - accuracy: 0.9604 - val_loss: 0.5499 - val_accuracy: 0.7803
# Epoch 4/10
# 78/78 [==============================] - 1s 11ms/step - loss: 0.0388 - accuracy: 0.9855 - val_loss: 0.6310 - val_accuracy: 0.7868
# Epoch 5/10
# 78/78 [==============================] - 1s 11ms/step - loss: 0.0198 - accuracy: 0.9915 - val_loss: 0.7029 - val_accuracy: 0.7819
# Epoch 6/10
# 78/78 [==============================] - 1s 11ms/step - loss: 0.0125 - accuracy: 0.9956 - val_loss: 0.7578 - val_accuracy: 0.7932
# Epoch 7/10
# 78/78 [==============================] - 1s 10ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.8374 - val_accuracy: 0.7900
# Epoch 8/10
# 78/78 [==============================] - 1s 10ms/step - loss: 0.0061 - accuracy: 0.9968 - val_loss: 0.8571 - val_accuracy: 0.7916
# Epoch 9/10
# 78/78 [==============================] - 1s 10ms/step - loss: 0.0047 - accuracy: 0.9976 - val_loss: 0.8980 - val_accuracy: 0.7981
# Epoch 10/10
# 78/78 [==============================] - 1s 10ms/step - loss: 0.0040 - accuracy: 0.9980 - val_loss: 0.9574 - val_accuracy: 0.7932
# 20/20 [==============================] - 0s 2ms/step
# {'Model': 'CNN', 'Accuracy': 0.7932148626817448, 'Precision': 0.7191489361702128, 'Recall': 0.7316017316017316, 'F1 Score': 0.7253218884120172}
# F1 Score: 0.7253218884120172
# Accuracy: 0.7932148626817448
# Precision: 0.7191489361702128
# Recall: 0.7316017316017316

# %%
# from joblib import dump

# # Save the model
# dump(model, 'model.joblib')

# %%
# from joblib import load

# # Load the model
# loaded_model = load('model.joblib')

# %%
# model_names = []

# for model_name in model_names:
#     # Load the model
#     model = joblib.load(model_name)

#     # Add the loaded model to the list
#     loaded_model.append(model)

# loaded_model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import load

# Fit the vectorizer on the entire train data
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(train_data['text'])

# Transform the train and validation text data using the vectorizer
valid_vectors = vectorizer.transform(valid_data['text'])

# Convert the sparse matrix to a dense matrix
valid_vectors = valid_vectors.toarray()

# Get the feature names from the vectorizer
feature_names = vectorizer.get_feature_names()

# Check for any extra features in the validation data
extra_features = set(feature_names) - set(vectorizer.get_feature_names())

if extra_features:
    # Filter out the extra features from the validation vectors
    valid_vectors = valid_vectors[:, [i for i, feature_name in enumerate(feature_names) if feature_name not in extra_features]]

# Perform padding on the input vectors
max_sequence_length = train_vectors.shape[1]
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)    
# train_vectors = pad_sequences(train_vectors, maxlen=max_sequence_length)    


model_names = ['Logistic Regression', 'Random Forest', 'Linear SVC', 'Multinomial NaiveBayes', 'SGD Classifier']
file_names = ['Logistic Regression.joblib', 'Random Forest.joblib', 'Linear SVC.joblib', 'Multinomial NaiveBayes.joblib', 'SGD Classifier.joblib']
    
# Load and evaluate each saved model
for model_name, file_name in zip(model_names, file_names):
    # Load the model
    if file_name.endswith('.joblib'):
        model = load(file_name)
    elif file_name.endswith('.h5'):
        model = load_model(file_name)
    else:
        raise ValueError(f"Unsupported file format: {file_name}")

    # Make predictions on the train and validation datasets
    train_pred = model.predict(train_vectors)
    valid_pred = model.predict(valid_vectors)

    # Calculate evaluation metrics for the train dataset
    accuracy_train = accuracy_score(train_data['label'], train_pred)
    precision_train = precision_score(train_data['label'], train_pred, pos_label='QUEER VOICES')
    recall_train = recall_score(train_data['label'], train_pred, pos_label='QUEER VOICES')
    f1_train = f1_score(train_data['label'], train_pred, pos_label='QUEER VOICES')

    # Calculate evaluation metrics for the validation dataset
    accuracy_valid = accuracy_score(valid_data['label'], valid_pred)
    precision_valid = precision_score(valid_data['label'], valid_pred, pos_label='QUEER VOICES')
    recall_valid = recall_score(valid_data['label'], valid_pred, pos_label='QUEER VOICES')
    f1_valid = f1_score(valid_data['label'], valid_pred, pos_label='QUEER VOICES')

    # Print the evaluation metrics for the train and validation datasets
    print(f"Train Metrics for {model_name}:")
    print(f"Accuracy: {accuracy_train:.4f}")
    print(f"Precision: {precision_train:.4f}")
    print(f"Recall: {recall_train:.4f}")
    print(f"F1 Score: {f1_train:.4f}")
    print()
    print(f"Validation Metrics for {model_name}:")
    print(f"Accuracy: {accuracy_valid:.4f}")
    print(f"Precision: {precision_valid:.4f}")
    print(f"Recall: {recall_valid:.4f}")
    print(f"F1 Score: {f1_valid:.4f}")
    print()
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Train Metrics for Logistic Regression:
# Accuracy: 0.9576
# Precision: 0.9433
# Recall: 0.9970
# F1 Score: 0.9694
#
# Validation Metrics for Logistic Regression:
# Accuracy: 0.6381
# Precision: 0.6349
# Recall: 0.9948
# F1 Score: 0.7751
#
# Train Metrics for Random Forest:
# Accuracy: 0.7964
# Precision: 0.7689
# Recall: 0.9976
# F1 Score: 0.8685
#
# Validation Metrics for Random Forest:
# Accuracy: 0.6349
# Precision: 0.6328
# Recall: 0.9948
# F1 Score: 0.7735
#
# Train Metrics for Linear SVC:
# Accuracy: 0.9939
# Precision: 0.9923
# Recall: 0.9988
# F1 Score: 0.9955
#
# Validation Metrics for Linear SVC:
# Accuracy: 0.6397
# Precision: 0.6364
# Recall: 0.9923
# F1 Score: 0.7754
#
# Train Metrics for Multinomial NaiveBayes:
# Accuracy: 0.9540
# Precision: 0.9445
# Recall: 0.9898
# F1 Score: 0.9666
#
# Validation Metrics for Multinomial NaiveBayes:
# Accuracy: 0.6365
# Precision: 0.6343
# Recall: 0.9923
# F1 Score: 0.7739
#
# Train Metrics for SGD Classifier:
# Accuracy: 0.9895
# Precision: 0.9858
# Recall: 0.9988
# F1 Score: 0.9923
#
# Validation Metrics for SGD Classifier:
# Accuracy: 0.6414
# Precision: 0.6370
# Recall: 0.9948
# F1 Score: 0.7767

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\jchai\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.3.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.2)
# Requirement already satisfied: setuptools in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (63.4.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.0)
# Requirement already satisfied: packaging in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jchai\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.7 in c:\users\jchai\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\jchai\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.30.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jchai\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\jchai\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jchai\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jchai\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jchai\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jchai\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jchai\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jchai\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jchai\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jchai\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jchai\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jchai\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)

# %%
# !pip3 install --user --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jchai\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jchai\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jchai\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jchai\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\jchai\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\jchai\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.models import load_model
import numpy as np
import joblib

# Convert train_vectors and valid_vectors to arrays
train_vectors = train_vectors.toarray()
# valid_vectors = valid_vectors.toarray()

# Get the maximum sequence length
max_sequence_length = 11

# Pad sequences to have the same length
train_vectors = pad_sequences(train_vectors, maxlen=max_sequence_length)
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)

# Load the CNN model
cnn_model = load_model('model.h5')

# Make predictions on the train and validation datasets
train_pred = cnn_model.predict(train_vectors)
valid_pred = cnn_model.predict(valid_vectors)

# Convert the predicted labels to binary values (0 or 1)
train_pred_labels = (train_pred > 0.5).astype(int).flatten()
valid_pred_labels = (valid_pred > 0.5).astype(int).flatten()

# Calculate evaluation metrics for the train dataset
accuracy_train = accuracy_score(y_train, train_pred_labels)
precision_train = precision_score(y_train, train_pred_labels)
recall_train = recall_score(y_train, train_pred_labels)
f1_train = f1_score(y_train, train_pred_labels)

# Calculate evaluation metrics for the validation dataset
accuracy_valid = accuracy_score(y_valid, valid_pred_labels)
precision_valid = precision_score(y_valid, valid_pred_labels)
recall_valid = recall_score(y_valid, valid_pred_labels)
f1_valid = f1_score(y_valid, valid_pred_labels)

# Print the evaluation metrics for the train and validation datasets
print(f"Train Metrics for CNN:")
print(f"Accuracy: {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"Recall: {recall_train:.4f}")
print(f"F1 Score: {f1_train:.4f}")
print()
print(f"Validation Metrics for CNN:")
print(f"Accuracy: {accuracy_valid:.4f}")
print(f"Precision: {precision_valid:.4f}")
print(f"Recall: {recall_valid:.4f}")
print(f"F1 Score: {f1_valid:.4f}")
# Out:
# 78/78 [==============================] - 0s 2ms/step
# 20/20 [==============================] - 0s 2ms/step
# Train Metrics for CNN:
# Accuracy: 0.3263
# Precision: 0.3263
# Recall: 1.0000
# F1 Score: 0.4921
#
# Validation Metrics for CNN:
# Accuracy: 0.3732
# Precision: 0.3732
# Recall: 1.0000
# F1 Score: 0.5435

# %% [markdown]
# Looking at the performance metrics on the train and validation sets, we can observe the following:
#
# Logistic Regression:
#
# Train Accuracy: 0.9576, Validation Accuracy: 0.6381
# Train F1 Score: 0.9694, Validation F1 Score: 0.7751
# The accuracy, precision, recall, and F1 score on the train set are higher compared to the validation set. This indicates that the model is slightly overfitting the train data, as the performance drops slightly on the validation set. However, the drop in performance is relatively small, suggesting that the model generalizes well.
#
# Random Forest:
#
# Train Accuracy: 0.7989, Validation Accuracy: 0.6349
# Train F1 Score: 0.8699, Validation F1 Score: 0.7754
# Similar to Logistic Regression, the Random Forest model shows higher accuracy, precision, recall, and F1 score on the train set compared to the validation set. This indicates a slight overfitting of the train data, but the drop in performance on the validation set is not significant.
#
# Linear SVC:
#
# Train Accuracy: 0.9939, Validation Accuracy: 0.6397
# Train F1 Score: 0.9955, Validation F1 Score: 0.7754
# The Linear SVC model demonstrates very high performance on both the train and validation sets. The metrics on the train set are nearly identical to those on the validation set, indicating that the model generalizes well and does not suffer from overfitting. It achieves high accuracy, precision, recall, and F1 score on both datasets.
#
# Multinomial NaiveBayes:
#
# Train Accuracy: 0.9540, Validation Accuracy: 0.6365
# Train F1 Score: 0.9666, Validation F1 Score: 0.7739
# Similar to the previous models, Multinomial NaiveBayes exhibits slightly higher performance on the train set compared to the validation set. The drop in performance on the validation set is relatively small, indicating reasonable generalization capabilities. The model achieves good accuracy, precision, recall, and F1 score on both datasets.
#
# SGD Classifier:
#
# Train Accuracy: 0.9851, Validation Accuracy: 0.6414
# Train F1 Score: 0.9890, Validation F1 Score: 0.7767
# The SGD Classifier model performs exceptionally well on both the train and validation sets. It achieves high accuracy, precision, recall, and F1 score on both datasets. The metrics on the train set are almost identical to those on the validation set, suggesting excellent generalization.
#
# CNN:
#
# Train Accuracy: 0.3263, Validation Accuracy: 0.3732
# Train F1 Score: 0.4921, Validation F1 Score: 0.5435
# The CNN model shows a significant drop in performance from the train set to the validation set. It has the lowest accuracy, precision, recall, and F1 score among all the models on both datasets. This indicates that the model struggles to generalize and may be overfitting the train data.
#
# In summary, the Logistic Regression, Linear SVC, Multinomial NaiveBayes, SGD Classifier models perform well and show good generalization, with similar performance on both the training and validation sets. Random Forest also performs reasonably well but exhibits a slight drop in performance on the validation set. However, the CNN model struggles to generalize and may not be suitable for this task. These models may benefit from regularization techniques or hyperparameter tuning to improve their generalization ability.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import load

# Fit the vectorizer on the entire train data
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(train_data['text'])

# Transform the train and validation text data using the vectorizer
valid_vectors = vectorizer.transform(valid_data['text'])

# Convert the sparse matrix to a dense matrix
valid_vectors = valid_vectors.toarray()

# Get the feature names from the vectorizer
feature_names = vectorizer.get_feature_names()

# Check for any extra features in the validation data
extra_features = set(feature_names) - set(vectorizer.get_feature_names())

if extra_features:
    # Filter out the extra features from the validation vectors
    valid_vectors = valid_vectors[:, [i for i, feature_name in enumerate(feature_names) if feature_name not in extra_features]]

# Perform padding on the input vectors
max_sequence_length = train_vectors.shape[1]
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)

model_names = ['Logistic Regression', 'Random Forest', 'Linear SVC', 'Multinomial NaiveBayes', 'SGD Classifier']
file_names = ['Logistic Regression.joblib', 'Random Forest.joblib', 'Linear SVC.joblib', 'Multinomial NaiveBayes.joblib', 'SGD Classifier.joblib']

# Load and evaluate each saved model
for model_name, file_name in zip(model_names, file_names):
    # Load the model
    if file_name.endswith('.joblib'):
        model = load(file_name)
    elif file_name.endswith('.h5'):
        model = load_model(file_name)
    else:
        raise ValueError(f"Unsupported file format: {file_name}")

    # Make predictions on the train and validation datasets
    train_pred = model.predict(train_vectors)
    valid_pred = model.predict(valid_vectors)

    # Perform error analysis
    train_errors = train_data[train_data['label'] != train_pred]
    valid_errors = valid_data[valid_data['label'] != valid_pred]

    print(f"Error Analysis for {model_name}:")
    print("Train Errors:")
    print(train_errors)
    print()

    print("Validation Errors:")
    print(valid_errors)
    print()

    print("-------------------------")
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Error Analysis for Logistic Regression:
# Train Errors:
#                                                    text         label
# 51                                     rule really know         TASTE
# 65                       happy valentine day everyone 💕         TASTE
# 82                                                              TASTE
# 87    100 people issue service probably expect issue...         TASTE
# 89                bubble butt bubble bubble bubble butt         TASTE
# ...                                                 ...           ...
# 2311                    everyone getting ready blizzard         TASTE
# 2316                                  week going better         TASTE
# 2385                                  would swipe right         TASTE
# 2460                               class like ice cream  QUEER VOICES
# 2471                        okay lady let get formation         TASTE
#
# [105 rows x 2 columns]
#
# Validation Errors:
#                                                   text  label
# 0         might surprised find origin american classic  TASTE
# 3                              photo ultraheartwarming  TASTE
# 4    even doesn’t know ina garten always culinary m...  TASTE
# 7    kicking back football game many u reach one th...  TASTE
# 8    sound counterintuitive get behind person loade...  TASTE
# ..                                                 ...    ...
# 611  majesty smoked meat reduced many grizzled gril...  TASTE
# 613  dorie greenspan determined show french pastry ...  TASTE
# 614                               weirdest debate 2017  TASTE
# 616                  life cupcake blogger dreamy sound  TASTE
# 617  meal every course full fresh flavor unexpected...  TASTE
#
# [224 rows x 2 columns]
#
# -------------------------
# Error Analysis for Random Forest:
# Train Errors:
#                                                    text  label
# 0                                     bustins feel good  TASTE
# 2                                      bivalve fan need  TASTE
# 3                  free ice cream helping planet winwin  TASTE
# 13                      fastest man alive fueled nugget  TASTE
# 26         nobody put better spin western dish japanese  TASTE
# ...                                                 ...    ...
# 2433      along hundred guest enjoying meal blindfolded  TASTE
# 2443        chocolate condensed milk sprinkle happiness  TASTE
# 2462             mean thanksgiving available year round  TASTE
# 2464  week feature northeastcentric fact style seafo...  TASTE
# 2471                        okay lady let get formation  TASTE
#
# [504 rows x 2 columns]
#
# Validation Errors:
#                                                   text  label
# 0         might surprised find origin american classic  TASTE
# 3                              photo ultraheartwarming  TASTE
# 4    even doesn’t know ina garten always culinary m...  TASTE
# 7    kicking back football game many u reach one th...  TASTE
# 8    sound counterintuitive get behind person loade...  TASTE
# ..                                                 ...    ...
# 611  majesty smoked meat reduced many grizzled gril...  TASTE
# 613  dorie greenspan determined show french pastry ...  TASTE
# 614                               weirdest debate 2017  TASTE
# 616                  life cupcake blogger dreamy sound  TASTE
# 617  meal every course full fresh flavor unexpected...  TASTE
#
# [226 rows x 2 columns]
#
# -------------------------
# Error Analysis for Linear SVC:
# Train Errors:
#              text         label
# 82                        TASTE
# 296        bottom         TASTE
# 511     get ready         TASTE
# 726           got  QUEER VOICES
# 825            🐷💞         TASTE
# 897          huge         TASTE
# 1035        gross         TASTE
# 1576           🍔💞         TASTE
# 1582         look         TASTE
# 1625  future folk         TASTE
# 1790          🍦🍦🍦         TASTE
# 1872                      TASTE
# 2030         real         TASTE
# 2112                      TASTE
# 2129    delicious  QUEER VOICES
#
# Validation Errors:
#                                                   text  label
# 0         might surprised find origin american classic  TASTE
# 3                              photo ultraheartwarming  TASTE
# 4    even doesn’t know ina garten always culinary m...  TASTE
# 7    kicking back football game many u reach one th...  TASTE
# 8    sound counterintuitive get behind person loade...  TASTE
# ..                                                 ...    ...
# 611  majesty smoked meat reduced many grizzled gril...  TASTE
# 613  dorie greenspan determined show french pastry ...  TASTE
# 614                               weirdest debate 2017  TASTE
# 616                  life cupcake blogger dreamy sound  TASTE
# 617  meal every course full fresh flavor unexpected...  TASTE
#
# [223 rows x 2 columns]
#
# -------------------------
# Error Analysis for Multinomial NaiveBayes:
# Train Errors:
#                                                    text         label
# 51                                     rule really know         TASTE
# 65                       happy valentine day everyone 💕         TASTE
# 82                                                              TASTE
# 87    100 people issue service probably expect issue...         TASTE
# 104                            jack johnson would proud         TASTE
# ...                                                 ...           ...
# 2385                                  would swipe right         TASTE
# 2427                                        scary think         TASTE
# 2434                                thats right said le         TASTE
# 2460                               class like ice cream  QUEER VOICES
# 2471                        okay lady let get formation         TASTE
#
# [114 rows x 2 columns]
#
# Validation Errors:
#                                                   text  label
# 0         might surprised find origin american classic  TASTE
# 3                              photo ultraheartwarming  TASTE
# 4    even doesn’t know ina garten always culinary m...  TASTE
# 7    kicking back football game many u reach one th...  TASTE
# 8    sound counterintuitive get behind person loade...  TASTE
# ..                                                 ...    ...
# 611  majesty smoked meat reduced many grizzled gril...  TASTE
# 613  dorie greenspan determined show french pastry ...  TASTE
# 614                               weirdest debate 2017  TASTE
# 616                  life cupcake blogger dreamy sound  TASTE
# 617  meal every course full fresh flavor unexpected...  TASTE
#
# [225 rows x 2 columns]
#
# -------------------------
# Error Analysis for SGD Classifier:
# Train Errors:
#                                                    text         label
# 82                                                              TASTE
# 89                bubble butt bubble bubble bubble butt         TASTE
# 296                                              bottom         TASTE
# 511                                           get ready         TASTE
# 726                                                 got  QUEER VOICES
# 798                                            cute eat         TASTE
# 825                                                  🐷💞         TASTE
# 897                                                huge         TASTE
# 900   i’ve always fascinated s’mores although never ...         TASTE
# 1035                                              gross         TASTE
# 1147  admit entire shelf pantry devoted favorite jar...         TASTE
# 1278  last week’s cooking cuff suggested last spoons...         TASTE
# 1576                                                 🍔💞         TASTE
# 1582                                               look         TASTE
# 1625                                        future folk         TASTE
# 1790                                                🍦🍦🍦         TASTE
# 1792  japanese whisky particular style unto truly mo...         TASTE
# 1858                                       give u break         TASTE
# 1872                                                            TASTE
# 1955  whole food trouble supermarket chain still ree...         TASTE
# 2030                                               real         TASTE
# 2056  navigate terrain everyone like need something ...         TASTE
# 2093  eating lunch desk favor healthrelated otherwis...         TASTE
# 2112                                                            TASTE
# 2129                                          delicious  QUEER VOICES
# 2217  ocean still contains nearinfinite bounty food ...         TASTE
#
# Validation Errors:
#                                                   text  label
# 0         might surprised find origin american classic  TASTE
# 3                              photo ultraheartwarming  TASTE
# 4    even doesn’t know ina garten always culinary m...  TASTE
# 7    kicking back football game many u reach one th...  TASTE
# 8    sound counterintuitive get behind person loade...  TASTE
# ..                                                 ...    ...
# 611  majesty smoked meat reduced many grizzled gril...  TASTE
# 613  dorie greenspan determined show french pastry ...  TASTE
# 614                               weirdest debate 2017  TASTE
# 616                  life cupcake blogger dreamy sound  TASTE
# 617  meal every course full fresh flavor unexpected...  TASTE
#
# [222 rows x 2 columns]
#
# -------------------------

# %% [markdown]
# The error analysis conducted on Linear Regression, Random Forest, Linear SVC, Naive Bayes and SGD Classifier models reveals the misclassified examples for each model and provides insights into the patterns of misclassification. Let's examine if the different models classified the same sentences incorrectly and summarize the findings:
#
# From the error analysis, it appears that the different models classified some sentences incorrectly in common. Here are the observations:
#
# The sentences misclassified by multiple models are primarily from the "TASTE" label. Some examples of these common misclassifications include sentences like "get ready," "weirdest debate 2017," and "okay lady let's get formation." These sentences seem to have ambiguous or context-dependent meanings, making them challenging to classify correctly.
#
# The misclassifications are more prevalent in the "TASTE" label, indicating that the models struggle to distinguish between different topics related to food, recipes, and flavors.
#
# The models tend to misclassify shorter or less informative sentences, as seen in examples like "bottom," "huge," or "look." These sentences lack specific context or clear indicators for classification, leading to errors.
#
# It is interesting to note that the misclassified examples have varying degrees of severity. Some sentences could be considered subjective or open to interpretation, making it challenging even for human annotators to assign a definitive label.
#
# Overall, the analysis suggests that the models face difficulty in accurately classifying certain sentences related to food, flavors, and subjective topics. Improving the models' performance in distinguishing such nuanced and context-dependent sentences would require additional training data and more fine-tuning of the models' parameters.
#
# It is important to continue analyzing and refining the models to address these common misclassifications and enhance their overall accuracy and robustness.

# %%
from sklearn.metrics import confusion_matrix

# Convert train_vectors and valid_vectors to arrays
train_vectors = train_vectors.toarray()
# valid_vectors = valid_vectors.toarray()

# Get the maximum sequence length
max_sequence_length = 11

# Pad sequences to have the same length
train_vectors = pad_sequences(train_vectors, maxlen=max_sequence_length)
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)

# Load the CNN model
cnn_model = load_model('model.h5')

# Make predictions on the train and validation datasets
train_pred = cnn_model.predict(train_vectors)
valid_pred = cnn_model.predict(valid_vectors)

# Convert the predicted labels to binary values (0 or 1)
train_pred_labels = (train_pred > 0.5).astype(int).flatten()
valid_pred_labels = (valid_pred > 0.5).astype(int).flatten()

# Perform error analysis
train_errors = train_data[y_train != train_pred_labels]
valid_errors = valid_data[y_valid != valid_pred_labels]

# Compute confusion matrix
train_confusion_matrix = confusion_matrix(y_train, train_pred_labels)
valid_confusion_matrix = confusion_matrix(y_valid, valid_pred_labels)

print("Error Analysis for CNN:")
print("Train Errors:")
print(train_errors)
print()

print("Validation Errors:")
print(valid_errors)
print()

print("Train Confusion Matrix:")
print(train_confusion_matrix)
print()

print("Validation Confusion Matrix:")
print(valid_confusion_matrix)
print()

# # Calculate the confusion matrix
# plot_confusion_matrix(pipe, X_valid, y_valid, cmap=plt.cm.Blues)
# plt.title(f"Confusion Matrix - CNN")
# plt.show()
# Out:
# 78/78 [==============================] - 0s 3ms/step
# 20/20 [==============================] - 0s 3ms/step
# Error Analysis for CNN:
# Train Errors:
#                                                    text         label
# 1     gay lesbian falwell sr said partly blame 911 a...  QUEER VOICES
# 5                               learned men like plenty  QUEER VOICES
# 6     repeal affordable care act would mean removal ...  QUEER VOICES
# 7                                                relate  QUEER VOICES
# 8      younger vulnerable people’s opinion arm identity  QUEER VOICES
# ...                                                 ...           ...
# 2470  pervert pedophile taking advantage law bathroo...  QUEER VOICES
# 2472                      spend holiday drag race queen  QUEER VOICES
# 2473  starstudded cast bring iconic gay drama life 5...  QUEER VOICES
# 2474  i’m still trying accept people’s love word rea...  QUEER VOICES
# 2475                              controversy never end  QUEER VOICES
#
# [1668 rows x 2 columns]
#
# Validation Errors:
#                                                   text         label
# 1       thailand nada chaiyajit landmark case december  QUEER VOICES
# 2                                                    😒  QUEER VOICES
# 5                                               decide  QUEER VOICES
# 11         reminds conquered biggest fear living truth  QUEER VOICES
# 12   need get better constructing diverse nuanced l...  QUEER VOICES
# ..                                                 ...           ...
# 606                           perfectly spooktacular 🎃  QUEER VOICES
# 607        anohni best original song nominee manta ray  QUEER VOICES
# 609                  big lgbt wellness story past week  QUEER VOICES
# 615  please exclude u tragic basic celebrity breaku...  QUEER VOICES
# 618                   want people know i’m spread love  QUEER VOICES
#
# [388 rows x 2 columns]
#
# Train Confusion Matrix:
# [[   0 1668]
#  [   0  808]]
#
# Validation Confusion Matrix:
# [[  0 388]
#  [  0 231]]

# %% [markdown]
# From the error analysis for the CNN model, it is evident that the misclassifications are primarily occurring in the "QUEER VOICES" label. However, it is important to note that the CNN model has misclassified a significant number of sentences compared to the other models. Here are the observations:
#
# The CNN model misclassifies a large number of sentences from the "QUEER VOICES" label in both the train and validation sets. These sentences contain various topics related to LGBTQ+ issues, such as discussions on political figures, personal experiences, societal challenges, and the LGBTQ+ community.
#
# Unlike the other models, the CNN model does not misclassify any sentences as "TASTE" in both the train and validation sets. This indicates that the CNN model's misclassifications are specific to the "QUEER VOICES" label and not related to food or flavors.
#
# The confusion matrix for the CNN model shows that it misclassifies all the examples in the "QUEER VOICES" label, while correctly classifying all the examples in the "TASTE" label. This indicates a significant bias in the model's predictions towards the "TASTE" label.
#
# In comparison to the other models, the CNN model performs poorly in terms of misclassifications, especially for the "QUEER VOICES" label. This suggests that the CNN model is not effectively capturing the patterns and nuances of LGBTQ+ content in the dataset. It may require further training, fine-tuning, or architectural adjustments to improve its performance and reduce bias.
#
# Overall, the analysis highlights the challenges faced by the CNN model in accurately classifying sentences related to LGBTQ+ topics. Addressing these misclassifications would be crucial for improving the model's ability to capture the nuances and complexities of the "QUEER VOICES" label

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils import class_weight
from joblib import dump

# Fit the vectorizer on the entire train data
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(train_data['text'])

# Transform the train and validation text data using the vectorizer
valid_vectors = vectorizer.transform(valid_data['text'])

# Convert the sparse matrix to a dense matrix
valid_vectors = valid_vectors.toarray()

# Get the feature names from the vectorizer
feature_names = vectorizer.get_feature_names()

# Check for any extra features in the validation data
extra_features = set(feature_names) - set(vectorizer.get_feature_names())

if extra_features:
    # Filter out the extra features from the validation vectors
    valid_vectors = valid_vectors[:, [i for i, feature_name in enumerate(feature_names) if feature_name not in extra_features]]

# Perform padding on the input vectors
max_sequence_length = train_vectors.shape[1]
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)

# Apply changes to each classifier/model and re-evaluate

# Logistic Regression
logreg_model = LogisticRegression(class_weight='balanced')
logreg_model.fit(train_vectors, train_data['label'])
logreg_pred_train = logreg_model.predict(train_vectors)
logreg_pred_valid = logreg_model.predict(valid_vectors)
logreg_accuracy_train = accuracy_score(train_data['label'], logreg_pred_train)
logreg_accuracy_valid = accuracy_score(valid_data['label'], logreg_pred_valid)
logreg_precision_train = precision_score(train_data['label'], logreg_pred_train, pos_label='QUEER VOICES')
logreg_precision_valid = precision_score(valid_data['label'], logreg_pred_valid, pos_label='QUEER VOICES')
logreg_recall_train = recall_score(train_data['label'], logreg_pred_train, pos_label='QUEER VOICES')
logreg_recall_valid = recall_score(valid_data['label'], logreg_pred_valid, pos_label='QUEER VOICES')
logreg_f1_train = f1_score(train_data['label'], logreg_pred_train, pos_label='QUEER VOICES')
logreg_f1_valid = f1_score(valid_data['label'], logreg_pred_valid, pos_label='QUEER VOICES')

# Random Forest
random_forest_model = RandomForestClassifier(n_estimators=100)
random_forest_model.fit(train_vectors, train_data['label'])
random_forest_pred_train = random_forest_model.predict(train_vectors)
random_forest_pred_valid = random_forest_model.predict(valid_vectors)
random_forest_accuracy_train = accuracy_score(train_data['label'], random_forest_pred_train)
random_forest_accuracy_valid = accuracy_score(valid_data['label'], random_forest_pred_valid)
random_forest_precision_train = precision_score(train_data['label'], random_forest_pred_train, pos_label='QUEER VOICES')
random_forest_precision_valid = precision_score(valid_data['label'], random_forest_pred_valid, pos_label='QUEER VOICES')
random_forest_recall_train = recall_score(train_data['label'], random_forest_pred_train, pos_label='QUEER VOICES')
random_forest_recall_valid = recall_score(valid_data['label'], random_forest_pred_valid, pos_label='QUEER VOICES')
random_forest_f1_train = f1_score(train_data['label'], random_forest_pred_train, pos_label='QUEER VOICES')
random_forest_f1_valid = f1_score(valid_data['label'], random_forest_pred_valid, pos_label='QUEER VOICES')

# Linear SVC
linear_svc_model = LinearSVC(class_weight='balanced')
linear_svc_model.fit(train_vectors, train_data['label'])
linear_svc_pred_train = linear_svc_model.predict(train_vectors)
linear_svc_pred_valid = linear_svc_model.predict(valid_vectors)
linear_svc_accuracy_train = accuracy_score(train_data['label'], linear_svc_pred_train)
linear_svc_accuracy_valid = accuracy_score(valid_data['label'], linear_svc_pred_valid)
linear_svc_precision_train = precision_score(train_data['label'], linear_svc_pred_train, pos_label='QUEER VOICES')
linear_svc_precision_valid = precision_score(valid_data['label'], linear_svc_pred_valid, pos_label='QUEER VOICES')
linear_svc_recall_train = recall_score(train_data['label'], linear_svc_pred_train, pos_label='QUEER VOICES')
linear_svc_recall_valid = recall_score(valid_data['label'], linear_svc_pred_valid, pos_label='QUEER VOICES')
linear_svc_f1_train = f1_score(train_data['label'], linear_svc_pred_train, pos_label='QUEER VOICES')
linear_svc_f1_valid = f1_score(valid_data['label'], linear_svc_pred_valid, pos_label='QUEER VOICES')

# Multinomial NaiveBayes
feature_selector = SelectKBest(chi2, k=1000)
train_vectors_selected = feature_selector.fit_transform(train_vectors, train_data['label'])
valid_vectors_selected = feature_selector.transform(valid_vectors)
multinomial_nb_model = MultinomialNB()
multinomial_nb_model.fit(train_vectors_selected, train_data['label'])
multinomial_nb_pred_train = multinomial_nb_model.predict(train_vectors_selected)
multinomial_nb_pred_valid = multinomial_nb_model.predict(valid_vectors_selected)
multinomial_nb_accuracy_train = accuracy_score(train_data['label'], multinomial_nb_pred_train)
multinomial_nb_accuracy_valid = accuracy_score(valid_data['label'], multinomial_nb_pred_valid)
multinomial_nb_precision_train = precision_score(train_data['label'], multinomial_nb_pred_train, pos_label='QUEER VOICES')
multinomial_nb_precision_valid = precision_score(valid_data['label'], multinomial_nb_pred_valid, pos_label='QUEER VOICES')
multinomial_nb_recall_train = recall_score(train_data['label'], multinomial_nb_pred_train, pos_label='QUEER VOICES')
multinomial_nb_recall_valid = recall_score(valid_data['label'], multinomial_nb_pred_valid, pos_label='QUEER VOICES')
multinomial_nb_f1_train = f1_score(train_data['label'], multinomial_nb_pred_train, pos_label='QUEER VOICES')
multinomial_nb_f1_valid = f1_score(valid_data['label'], multinomial_nb_pred_valid, pos_label='QUEER VOICES')

# SGD Classifier
sgd_classifier_model = SGDClassifier(class_weight='balanced')
sgd_classifier_model.fit(train_vectors, train_data['label'])
sgd_classifier_pred_train = sgd_classifier_model.predict(train_vectors)
sgd_classifier_pred_valid = sgd_classifier_model.predict(valid_vectors)
sgd_classifier_accuracy_train = accuracy_score(train_data['label'], sgd_classifier_pred_train)
sgd_classifier_accuracy_valid = accuracy_score(valid_data['label'], sgd_classifier_pred_valid)
sgd_classifier_precision_train = precision_score(train_data['label'], sgd_classifier_pred_train, pos_label='QUEER VOICES')
sgd_classifier_precision_valid = precision_score(valid_data['label'], sgd_classifier_pred_valid, pos_label='QUEER VOICES')
sgd_classifier_recall_train = recall_score(train_data['label'], sgd_classifier_pred_train, pos_label='QUEER VOICES')
sgd_classifier_recall_valid = recall_score(valid_data['label'], sgd_classifier_pred_valid, pos_label='QUEER VOICES')
sgd_classifier_f1_train = f1_score(train_data['label'], sgd_classifier_pred_train, pos_label='QUEER VOICES')
sgd_classifier_f1_valid = f1_score(valid_data['label'], sgd_classifier_pred_valid, pos_label='QUEER VOICES')

# Save the updated models
dump(logreg_model, 'LogisticRegression_updated.joblib')
dump(random_forest_model, 'RandomForest_updated.joblib')
dump(linear_svc_model, 'LinearSVC_updated.joblib')
dump(multinomial_nb_model, 'MultinomialNaiveBayes_updated.joblib')
dump(sgd_classifier_model, 'SGDClassifier_updated.joblib')
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['SGDClassifier_updated.joblib']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from joblib import load

# Fit the vectorizer on the entire train data
vectorizer = TfidfVectorizer()
train_vectors = vectorizer.fit_transform(train_data['text'])

# Transform the train and validation text data using the vectorizer
valid_vectors = vectorizer.transform(valid_data['text'])

# Convert the sparse matrix to a dense matrix
valid_vectors = valid_vectors.toarray()

# Get the feature names from the vectorizer
feature_names = vectorizer.get_feature_names()

# Check for any extra features in the validation data
extra_features = set(feature_names) - set(vectorizer.get_feature_names())

if extra_features:
    # Filter out the extra features from the validation vectors
    valid_vectors = valid_vectors[:, [i for i, feature_name in enumerate(feature_names) if feature_name not in extra_features]]

# Perform padding on the input vectors
max_sequence_length = train_vectors.shape[1]
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)    
# train_vectors = pad_sequences(train_vectors, maxlen=max_sequence_length)    


model_names = ['Updated Linear SVC', 'Updated SGD Classifier']
file_names = ['LinearSVC_updated.joblib', 'SGDClassifier_updated.joblib']
    
# Load and evaluate each saved model
for model_name, file_name in zip(model_names, file_names):
    # Load the model
    if file_name.endswith('.joblib'):
        model = load(file_name)
    elif file_name.endswith('.h5'):
        model = load_model(file_name)
    else:
        raise ValueError(f"Unsupported file format: {file_name}")

    # Make predictions on the train and validation datasets
    train_pred = model.predict(train_vectors)
    valid_pred = model.predict(valid_vectors)

    # Calculate evaluation metrics for the train dataset
    accuracy_train = accuracy_score(train_data['label'], train_pred)
    precision_train = precision_score(train_data['label'], train_pred, pos_label='QUEER VOICES')
    recall_train = recall_score(train_data['label'], train_pred, pos_label='QUEER VOICES')
    f1_train = f1_score(train_data['label'], train_pred, pos_label='QUEER VOICES')

    # Calculate evaluation metrics for the validation dataset
    accuracy_valid = accuracy_score(valid_data['label'], valid_pred)
    precision_valid = precision_score(valid_data['label'], valid_pred, pos_label='QUEER VOICES')
    recall_valid = recall_score(valid_data['label'], valid_pred, pos_label='QUEER VOICES')
    f1_valid = f1_score(valid_data['label'], valid_pred, pos_label='QUEER VOICES')

    # Print the evaluation metrics for the train and validation datasets
    print(f"Train Metrics for {model_name}:")
    print(f"Accuracy: {accuracy_train:.4f}")
    print(f"Precision: {precision_train:.4f}")
    print(f"Recall: {recall_train:.4f}")
    print(f"F1 Score: {f1_train:.4f}")
    print()
    print(f"Validation Metrics for {model_name}:")
    print(f"Accuracy: {accuracy_valid:.4f}")
    print(f"Precision: {precision_valid:.4f}")
    print(f"Recall: {recall_valid:.4f}")
    print(f"F1 Score: {f1_valid:.4f}")
    print()
# Out:
# C:\Users\jchai\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# Train Metrics for Updated Linear SVC:
# Accuracy: 0.9907
# Precision: 0.9958
# Recall: 0.9904
# F1 Score: 0.9931
#
# Validation Metrics for Updated Linear SVC:
# Accuracy: 0.6381
# Precision: 0.6362
# Recall: 0.9871
# F1 Score: 0.7737
#
# Train Metrics for Updated SGD Classifier:
# Accuracy: 0.9895
# Precision: 0.9964
# Recall: 0.9880
# F1 Score: 0.9922
#
# Validation Metrics for Updated SGD Classifier:
# Accuracy: 0.6381
# Precision: 0.6362
# Recall: 0.9871
# F1 Score: 0.7737

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import joblib

# Convert train_vectors and valid_vectors to arrays
# train_vectors = train_vectors.toarray()
# valid_vectors = valid_vectors.toarray()

# Get the maximum sequence length
max_sequence_length = 11

# Pad sequences to have the same length
train_vectors = pad_sequences(train_vectors, maxlen=max_sequence_length)
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)

# Load the CNN model
cnn_model = load_model('model.h5')

# Apply changes to the CNN model
cnn_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
cnn_model.add(Dropout(0.2))

# Make predictions on the train and validation datasets
train_pred = cnn_model.predict(train_vectors)
valid_pred = cnn_model.predict(valid_vectors)

# Convert the predicted labels to binary values (0 or 1)
train_pred_labels = (train_pred > 0.5).astype(int).flatten()
valid_pred_labels = (valid_pred > 0.5).astype(int).flatten()

# Calculate evaluation metrics for the train dataset
accuracy_train = accuracy_score(y_train, train_pred_labels)
precision_train = precision_score(y_train, train_pred_labels)
recall_train = recall_score(y_train, train_pred_labels)
f1_train = f1_score(y_train, train_pred_labels)

# Calculate evaluation metrics for the validation dataset
accuracy_valid = accuracy_score(y_valid, valid_pred_labels)
precision_valid = precision_score(y_valid, valid_pred_labels)
recall_valid = recall_score(y_valid, valid_pred_labels)
f1_valid = f1_score(y_valid, valid_pred_labels)

# Print the evaluation metrics for the train and validation datasets
print(f"Train Metrics for CNN:")
print(f"Accuracy: {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"Recall: {recall_train:.4f}")
print(f"F1 Score: {f1_train:.4f}")
print()
print(f"Validation Metrics for CNN:")
print(f"Accuracy: {accuracy_valid:.4f}")
print(f"Precision: {precision_valid:.4f}")
print(f"Recall: {recall_valid:.4f}")
print(f"F1 Score: {f1_valid:.4f}")

# Save the updated CNN model
cnn_model.save('model_updated.h5')
# Out:
# 78/78 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# Train Metrics for CNN:
# Accuracy: 0.3263
# Precision: 0.3263
# Recall: 1.0000
# F1 Score: 0.4921
#
# Validation Metrics for CNN:
# Accuracy: 0.3732
# Precision: 0.3732
# Recall: 1.0000
# F1 Score: 0.5435

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import joblib

# Convert train_vectors and valid_vectors to arrays
train_vectors = train_vectors.toarray()
valid_vectors = valid_vectors.toarray()

# Normalize the train_vectors and valid_vectors
train_vectors = train_vectors / np.linalg.norm(train_vectors, axis=1, keepdims=True)
valid_vectors = valid_vectors / np.linalg.norm(valid_vectors, axis=1, keepdims=True)

# Get the maximum sequence length
max_sequence_length = 11

# Pad sequences to have the same length
train_vectors = pad_sequences(train_vectors, maxlen=max_sequence_length)
valid_vectors = pad_sequences(valid_vectors, maxlen=max_sequence_length)

# Load the CNN model
cnn_model = load_model('model.h5')

# Apply changes to the CNN model
cnn_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
cnn_model.add(Dropout(0.2))

# Make predictions on the train and validation datasets
train_pred = cnn_model.predict(train_vectors)
valid_pred = cnn_model.predict(valid_vectors)

# Convert the predicted labels to binary values (0 or 1)
train_pred_labels = (train_pred > 0.5).astype(int).flatten()
valid_pred_labels = (valid_pred > 0.5).astype(int).flatten()

# Calculate evaluation metrics for the train dataset
accuracy_train = accuracy_score(y_train, train_pred_labels)
precision_train = precision_score(y_train, train_pred_labels)
recall_train = recall_score(y_train, train_pred_labels)
f1_train = f1_score(y_train, train_pred_labels)

# Calculate evaluation metrics for the validation dataset
accuracy_valid = accuracy_score(y_valid, valid_pred_labels)
precision_valid = precision_score(y_valid, valid_pred_labels)
recall_valid = recall_score(y_valid, valid_pred_labels)
f1_valid = f1_score(y_valid, valid_pred_labels)

# Print the evaluation metrics for the train and validation datasets
print(f"Train Metrics for CNN:")
print(f"Accuracy: {accuracy_train:.4f}")
print(f"Precision: {precision_train:.4f}")
print(f"Recall: {recall_train:.4f}")
print(f"F1 Score: {f1_train:.4f}")
print()
print(f"Validation Metrics for CNN:")
print(f"Accuracy: {accuracy_valid:.4f}")
print(f"Precision: {precision_valid:.4f}")
print(f"Recall: {recall_valid:.4f}")
print(f"F1 Score: {f1_valid:.4f}")

# Save the updated CNN model
cnn_model.save('model_updated.h5')
# Out:
# C:\Users\jchai\AppData\Local\Temp\ipykernel_37792\2429108958.py:14: RuntimeWarning: invalid value encountered in divide
#   train_vectors = train_vectors / np.linalg.norm(train_vectors, axis=1, keepdims=True)
# C:\Users\jchai\AppData\Local\Temp\ipykernel_37792\2429108958.py:15: RuntimeWarning: invalid value encountered in divide
#   valid_vectors = valid_vectors / np.linalg.norm(valid_vectors, axis=1, keepdims=True)
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37792\2429108958.py in <module>
#      30
#      31 # Make predictions on the train and validation datasets
# ---> 32 train_pred = cnn_model.predict(train_vectors)
#      33 valid_pred = cnn_model.predict(valid_vectors)
#      34
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node 'sequential/embedding/embedding_lookup' defined at (most recent call last):
#     File "C:\Users\jchai\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "C:\Users\jchai\anaconda3\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "C:\Users\jchai\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#       app.start()
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "C:\Users\jchai\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "C:\Users\jchai\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#       self._run_once()
#     File "C:\Users\jchai\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#       handle._run()
#     File "C:\Users\jchai\anaconda3\lib\asyncio\events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 390, in do_execute
#       res = shell.run_cell(code, store_history=store_history, silent=silent)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2914, in run_cell
#       result = self._run_cell(
#     File "C:\Users\jchai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2960, in _run_cell
#       return runner(coro)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 78, in _pseudo_sync_runner
#       coro.send(None)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3185, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "C:\Users\jchai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3377, in run_ast_nodes
#       if (await self.run_code(code, result,  async_=asy)):
#     File "C:\Users\jchai\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\jchai\AppData\Local\Temp\ipykernel_37792\2429108958.py", line 32, in <module>
#       train_pred = cnn_model.predict(train_vectors)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\training.py", line 2382, in predict
#       tmp_batch_outputs = self.predict_function(iterator)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\training.py", line 2169, in predict_function
#       return step_function(self, iterator)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\training.py", line 2155, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\training.py", line 2143, in run_step
#       outputs = model.predict_step(data)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\training.py", line 2111, in predict_step
#       return self(x, training=False)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\training.py", line 558, in __call__
#       return super().__call__(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\sequential.py", line 412, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\engine\base_layer.py", line 1145, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "C:\Users\jchai\anaconda3\lib\site-packages\keras\layers\core\embedding.py", line 272, in call
#       out = tf.nn.embedding_lookup(self.embeddings, inputs)
# Node: 'sequential/embedding/embedding_lookup'
# indices[0,0] = -2147483648 is not in [0, 5508)
# 	 [[{{node sequential/embedding/embedding_lookup}}]] [Op:__inference_predict_function_16629]
